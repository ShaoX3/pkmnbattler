# %%
import time, random, os, logging
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

# %%
pkdf = pd.read_csv("Pokemon2.csv")
movedf = pd.read_csv("Pokemon_move_type.csv")
def checkUsable(move):
    return not ("0" in move.text)
def wait():
    try:
        return driver.find_element_by_name("chooseMove").is_displayed()
    except:
        return False
def wait1():
    try:
        return driver.find_element_by_name("chooseSwitch").is_displayed()
    except:
        return False
def canSkip():
    try:
        return driver.find_element_by_name("goToEnd").is_displayed()
    except:
        return False
def getswitches():
    try:
        return driver.find_elements_by_name("chooseSwitch")
    except:
        return []
def getcurr():
    try:
        return driver.find_elements_by_name("chooseDisabled")
    except:
        return []
def getmoves():
    try:
        return driver.find_elements_by_name("chooseMove")
    except:
        return []
def gameNotOver():
    try:
        return not (driver.find_element_by_name("closeAndRematch").is_displayed())
    except:
        return True
def timerOn():
    try:
        return driver.find_element_by_name("openTimer").is_displayed()
    except:
        return False
def checkOurSub():
    try:
        xroom = "//*[@id='" + room
        our_sub_xpath = xroom + "']/div[1]/div/div[5]/div[3]/img[1]"
        return driver.find_element_by_xpath(our_sub_xpath).is_displayed()
    except:
        return False
def getExtensionInfo():
    xroom = "//*[@id='" + room
    extension_infos = []
    for j in range(2,6):
        extension_xpath = xroom + "']/div[1]/div/div[9]/div/strong["+ str(j) + "]"
        toolbar = driver.find_element_by_xpath(extension_xpath)
        hover = ActionChains(driver).move_to_element(toolbar)
        hover.perform()
        extension_info = driver.find_element_by_class_name("tooltip").text
        extension_infos.append(extension_info)
        
def getourP():
    room = driver.find_element_by_class_name("ps-room-opaque").get_attribute("id")
    p = driver.find_element_by_class_name("lstatbar")
    available_p = getswitches()
    curr_p = getcurr()
    all_p = curr_p + available_p
    our_p_info = []
    """hover over enemy pokemon and collect info from the popup"""
    s = "//*[@id='" + room +"']/div[2]/div[3]"
    curr_em = driver.find_element_by_xpath(s)
    hover = ActionChains(driver).move_to_element(curr_em)
    hover.perform()
    for i in range(len(all_p)):
        hover = ActionChains(driver).move_to_element(all_p[i])
        hover.perform()
        a = driver.find_element_by_class_name("tooltip")
        our_p_info.append(a.text)
    return our_p_info

def getOppInfo():
    oppCurr = {}
    d = "//*[@id='" + room +"']/div[2]/div[3]"
    curr_em = driver.find_element_by_xpath(d)
    hover = ActionChains(driver).move_to_element(curr_em)
    hover.perform()
    a = driver.find_element_by_class_name("tooltip")
    pinfo = a.text.split("\n")
    namelvl = pinfo[0].split(' L')
    name = namelvl[0]
    lvl = namelvl[1]
    oppCurr['Name'] = name
    oppCurr['Level'] = lvl
    oppCurr["types"] = searchType(name)
    return oppCurr

def make1Pkdict(p):

    dic = {'Name': '',
           'Level': '',
           'Atk': '', 
           'Def': '', 
           'SpA': '',
           'SpD': '',
           'Spe': '',
           'Boosts': [1, 1, 1, 1],
           'Ability': '',
           'Item': '',
           'Status': None,
           'HP%': '',
           'HP': '',
           'Moveset': {},
           }
    
    pinfo = p.split('\n')
    namelvl = pinfo[0].split(' L')
    name = namelvl[0]
    lvl = namelvl[1]
    dic['Name'] = name
    dic['Level'] = lvl
    hp = pinfo[1][4:].split(" ")
    dic['HP%'] = hp[0]
    dic['HP'] = hp[1]
    lst = pinfo[2].split(' / ')
    abi = lst[0].split(': ')
    dic[abi[0]] = abi[1]
    print(lst[0])
    print(lst[1])
    item = lst[1].split(": ")
    dic[item[0]] = item[1]
    stats = pinfo[3].split(" / ")
    for stat in stats:
        st = stat.split(" ")
        dic[st[1]] = st[0]
    for i in range(4,8):
        move = pinfo[i].split("• ")[1]
        dic["Moveset"][move] = i - 4
    return dic

def searchType(name):
    row = pkdf[pkdf["Name"]== name]
    types = [row["Type 1"][row.index[0]]]
    if not pd.isna(row["Type 2"][row.index[0]]):
        types.append(row["Type 2"][row.index[0]])
    return types

def movetype(move):
    try:
        row = movedf[movedf["move"] == move]
        return row["type"][row.index[0]]
    except:
        return "Normal"

# %%
"""initialize driver with the pokemon extension"""
chrome_path= r"./chromedriver"
options = Options()
options.add_extension("./Pokemon-Showdown-Random-Battle-Tooltip_v2.2.crx")
driver = webdriver.Chrome(executable_path=chrome_path, chrome_options = options)

driver.get("https://play.pokemonshowdown.com/")
time.sleep(4)
driver.find_element_by_xpath("""//*[@id="room-"]/div/div[1]/div[2]/div[1]/form/p[3]/button""").click()
time.sleep(0.5)
usernameinput = driver.find_element_by_xpath("""/html/body/div[4]/div/form/p[1]/label/input""")
time.sleep(1)
name1 = 'testing34234'+ str(random.randint(1,1000))
usernameinput.send_keys(name1)
time.sleep(0.5)
driver.find_element_by_xpath("""/html/body/div[4]/div/form/p[2]/button[1]""").click()

"""playing with random player"""
time.sleep(2)
# driver.find_element_by_xpath("""//*[@id="room-"]/div/div[1]/div[2]/div[1]/form/p[3]/button""").click()


"""for playing with an specific username to battle """
driver.find_element_by_xpath("""//*[@id="room-"]/div/div[1]/div[2]/div[3]/p[2]/button""").click()
opp = driver.find_element_by_xpath("""/html/body/div[4]/form/p[1]/label/input""")
opp.send_keys("timzzz")
time.sleep(0.5)
driver.find_element_by_xpath("""/html/body/div[4]/form/p[2]/button[1]""").click()
time.sleep(4)
driver.find_element_by_xpath("""/html/body/div[4]/div/p/button[1]""").click()
driver.find_element_by_xpath("""//*[@id="room-"]/div/div[1]/div[1]/div/div[1]/div[1]/form/p[4]/button[1]""").click()


"""mutes the game"""
time.sleep(10)
driver.find_element_by_xpath("""//*[@id="header"]/div[3]/button[1]/i""").click()
time.sleep(0.5)
driver.find_element_by_name("muted").click()
time.sleep(0.5)
driver.find_element_by_xpath("""//*[@id="header"]/div[3]/button[1]/i""").click()
"""starts timer"""

#if (timerOn()):
#    time.sleep(0.5)
#    driver.find_element_by_name("openTimer").click()
#    driver.find_element_by_name("timerOn").click()

room = driver.find_element_by_class_name("ps-room-opaque").get_attribute("id")
time.sleep(5)
our_ps = getourP()
"""makes a list of dictionary of our pokemons"""

our_ps_dic = {}
for p in our_ps:
    d = make1Pkdict(p)
    our_ps_dic[d["Name"]] = d
turn = 0
currp = our_ps[0].split(" L")[0]
# while gameNotOver():
#     turn += 1
time.sleep(1)
if canSkip():
    driver.find_element_by_name("goToEnd").click()
available_p = getswitches()
available_m = getmoves()
possibles = available_m + available_p
# if (len(possibles) == 0):
#     continue
i = random.randint(0, len(possibles) - 1)
possibles[i].click()
# while ((not (wait() or wait1())) and gameNotOver()):
#     time.sleep(2)
log = driver.find_element_by_css_selector(".battle-log")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: use options instead of chrome_options
#   """
# Ability: Drizzle
# Item: Leftovers
# Ability: Dry Skin
# Item: Leftovers
# Ability: Frisk
# Item: Leftovers
# Ability: Water Absorb
# Item: Assault Vest
# Ability: Illusion
# Item: Life Orb
# Ability: Shell Armor
# Item: White Herb

# %%
a = log.text

# %%
getOppInfo()
# Out:
# {'Name': 'Houndoom', 'Level': '78', 'types': ['Dark', 'Fire']}

# %%
dic
# Out:
# {'Name': 'Houndoom', 'Level': '78'}

# %%
our_ps_dic
# Out:
# {'Pelipper': {'Name': 'Pelipper',
#   'Level': '79',
#   'Atk': '125',
#   'Def': '204',
#   'SpA': '196',
#   'SpD': '156',
#   'Spe': '148',
#   'Boosts': [1, 1, 1, 1],
#   'Ability': 'Drizzle',
#   'Item': 'Leftovers',
#   'Status': None,
#   'HP%': '100.0%',
#   'HP': '(223/223)',
#   'Moveset': {'Scald': 0, 'Knock Off': 1, 'Toxic': 2, 'Roost': 3}},
#  'Jynx': {'Name': 'Jynx',
#   'Level': '83',
#   'Atk': '88',
#   'Def': '106',
#   'SpA': '239',
#   'SpD': '205',
#   'Spe': '205',
#   'Boosts': [1, 1, 1, 1],
#   'Ability': 'Dry Skin',
#   'Item': 'Leftovers',
#   'Status': None,
#   'HP%': '100.0%',
#   'HP': '(243/243)',
#   'Moveset': {'Nasty Plot': 0,
#    'Psyshock': 1,
#    'Lovely Kiss': 2,
#    'Ice Beam': 3}},
#  'Gourgeist (Gourgeist-Super)': {'Name': 'Gourgeist (Gourgeist-Super)',
#   'Level': '83',
#   'Atk': '214',
#   'Def': '250',
#   'SpA': '144',
#   'SpD': '172',
#   'Spe': '137',
#   'Boosts': [1, 1, 1, 1],
#   'Ability': 'Frisk',
#   'Item': 'Leftovers',
#   'Status': None,
#   'HP%': '100.0%',
#   'HP': '(277/277)',
#   'Moveset': {'Will-O-Wisp': 0,
#    'Leech Seed': 1,
#    'Shadow Sneak': 2,
#    'Seed Bomb': 3}},
#  'Seismitoad': {'Name': 'Seismitoad',
#   'Level': '81',
#   'Atk': '201',
#   'Def': '168',
#   'SpA': '184',
#   'SpD': '168',
#   'Spe': '167',
#   'Boosts': [1, 1, 1, 1],
#   'Ability': 'Water Absorb',
#   'Item': 'Assault Vest',
#   'Status': None,
#   'HP%': '100.0%',
#   'HP': '(303/303)',
#   'Moveset': {'Earthquake': 0,
#    'Hydro Pump': 1,
#    'Sludge Wave': 2,
#    'Knock Off': 3}},
#  'Zoroark': {'Name': 'Zoroark',
#   'Level': '83',
#   'Atk': '222',
#   'Def': '147',
#   'SpA': '247',
#   'SpD': '147',
#   'Spe': '222',
#   'Boosts': [1, 1, 1, 1],
#   'Ability': 'Illusion',
#   'Item': 'Life Orb',
#   'Status': None,
#   'HP%': '100.0%',
#   'HP': '(235/235)',
#   'Moveset': {'Nasty Plot': 0,
#    'Sludge Bomb': 1,
#    'Dark Pulse': 2,
#    'Sucker Punch': 3}},
#  'Turtonator': {'Name': 'Turtonator',
#   'Level': '83',
#   'Atk': '177',
#   'Def': '272',
#   'SpA': '199',
#   'SpD': '189',
#   'Spe': '107',
#   'Boosts': [1, 1, 1, 1],
#   'Ability': 'Shell Armor',
#   'Item': 'White Herb',
#   'Status': None,
#   'HP%': '100.0%',
#   'HP': '(235/235)',
#   'Moveset': {'Draco Meteor': 0,
#    'Fire Blast': 1,
#    'Shell Smash': 2,
#    'Earthquake': 3}}}

# %%
a.replace("\n", " ")
# Out:
# "Battle Options ☆testing34234401 joined. ☆timzzz joined. Format: [Gen 7] Random Battle Sleep Clause Mod: Limit one foe put to sleep HP Percentage Mod: HP is shown in percentages Battle between testing34234401 and timzzz started! Go! Pelipper! timzzz sent out Houndoom! [Pelipper's Drizzle!] It started to rain! Turn 1"

# %%
log = driver.find_element_by_css_selector(".battle-log")
blog = log.text.replace("\n","").split("Turn " + str(1))[1].split("!")
for i in range(len(blog)):
    curr = blog[i]
    if "opposing" in curr:
        print(curr)
    if 
blog

# %%
"""hover over enemy pokemon and collect info from the popup"""
s = "//*[@id='" + room +"']/div[2]/div[3]"
curr_em = driver.find_element_by_xpath(s)
hover = ActionChains(driver).move_to_element(curr_em)
hover.perform()
opp_pk_info = driver.find_element_by_class_name("tooltip")

# %%
"""use this to help concatenate your xpath"""
xroom = "//*[@id='" + room

extension_infos = []
for j in range(2,6):
    extension_xpath = xroom + "']/div[1]/div/div[9]/div/strong["+ str(j) + "]"
    toolbar = driver.find_element_by_xpath(extension_xpath)
    hover = ActionChains(driver).move_to_element(toolbar)
    hover.perform()
    extension_info = driver.find_element_by_class_name("tooltip").text
    print(extension_info)
    extension_infos.append(extension_info)
